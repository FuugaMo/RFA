# %%
import csv
import cv2
import itertools
import numpy as np
import pandas as pd
import os
import sys
import tempfile
import tqdm

from matplotlib import pyplot as plt
from matplotlib.collections import LineCollection

import tensorflow as tf
import tensorflow_hub as hub
from tensorflow import keras

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
#@title Functions to run pose estimation with MoveNet

#@markdown You'll download the MoveNet Thunder model from [TensorFlow Hub](https://www.google.com/url?sa=D&q=https%3A%2F%2Ftfhub.dev%2Fs%3Fq%3Dmovenet), and reuse some inference and visualization logic from the [MoveNet Raspberry Pi (Python)](https://github.com/tensorflow/examples/tree/master/lite/examples/pose_estimation/raspberry_pi) sample app to detect landmarks (ear, nose, wrist etc.) from the input images.

#@markdown *Note: You should use the most accurate pose estimation model (i.e. MoveNet Thunder) to detect the keypoints and use them to train the pose classification model to achieve the best accuracy. When running inference, you can use a pose estimation model of your choice (e.g. either MoveNet Lightning or Thunder).*

# Download model from TF Hub and check out inference code from GitHub
# !wget -q -O movenet_thunder.tflite https://tfhub.dev/google/lite-model/movenet/singlepose/thunder/tflite/float16/4?lite-format=tflite
# !git clone https://github.com/tensorflow/examples.git

# %%
pose_sample_rpi_path = '/Users/fuugamo/Documents/CV/rfa_-project/examples/lite/examples/pose_estimation/raspberry_pi'

sys.path.append(pose_sample_rpi_path)

# Load MoveNet Thunder model
import utils
from data import BodyPart
from ml import Movenet

movenet = Movenet('movenet_thunder')


# Define function to run pose estimation using MoveNet Thunder.
# You'll apply MoveNet's cropping algorithm and run inference multiple times on
# the input image to improve pose estimation accuracy.
def detect(input_tensor, inference_count=3):
    """Runs detection on an input image.
 
  Args:
    input_tensor: A [height, width, 3] Tensor of type tf.float32.
      Note that height and width can be anything since the image will be
      immediately resized according to the needs of the model within this
      function.
    inference_count: Number of times the model should run repeatly on the
      same input image to improve detection accuracy.
 
  Returns:
    A Person entity detected by the MoveNet.SinglePose.
  """
    image_height, image_width, channel = input_tensor.shape

    # Detect pose using the full input image
    movenet.detect(input_tensor.numpy(), reset_crop_region=True)

    # Repeatedly using previous detection result to identify the region of
    # interest and only croping that region to improve detection accuracy
    for _ in range(inference_count - 1):
        person = movenet.detect(input_tensor.numpy(), reset_crop_region=False)

    return person
# Out:
# INFO: Initialized TensorFlow Lite runtime.
# INFO: Applying 1 TensorFlow Lite delegate(s) lazily.

# %%
#@title Functions to visualize the pose estimation results.


def draw_prediction_on_image(image,
                             person,
                             crop_region=None,
                             close_figure=True,
                             keep_input_size=False):
    """Draws the keypoint predictions on image.
 
  Args:
    image: An numpy array with shape [height, width, channel] representing the
      pixel values of the input image.
    person: A person entity returned from the MoveNet.SinglePose model.
    close_figure: Whether to close the plt figure after the function returns.
    keep_input_size: Whether to keep the size of the input image.
 
  Returns:
    An numpy array with shape [out_height, out_width, channel] representing the
    image overlaid with keypoint predictions.
  """
    # Draw the detection result on top of the image.
    image_np = utils.visualize(image, [person])

    # Plot the image with detection results.
    height, width, channel = image.shape
    aspect_ratio = float(width) / height
    fig, ax = plt.subplots(figsize=(12 * aspect_ratio, 12))
    im = ax.imshow(image_np)

    if close_figure:
        plt.close(fig)

    if not keep_input_size:
        image_np = utils.keep_aspect_ratio_resizer(image_np, (512, 512))

    return image_np

# %%
#@title Code to load the images, detect pose landmarks and save them into a CSV file


class MoveNetPreprocessor(object):
    """Helper class to preprocess pose sample images for classification."""

    def __init__(self, images_in_folder, images_out_folder, csvs_out_path):
        """Creates a preprocessor to detection pose from images and save as CSV.

    Args:
      images_in_folder: Path to the folder with the input images. It should
        follow this structure:
        yoga_poses
        |__ downdog
            |______ 00000128.jpg
            |______ 00000181.bmp
            |______ ...
        |__ goddess
            |______ 00000243.jpg
            |______ 00000306.jpg
            |______ ...
        ...
      images_out_folder: Path to write the images overlay with detected
        landmarks. These images are useful when you need to debug accuracy
        issues.
      csvs_out_path: Path to write the CSV containing the detected landmark
        coordinates and label of each image that can be used to train a pose
        classification model.
    """
        self._images_in_folder = images_in_folder
        self._images_out_folder = images_out_folder
        self._csvs_out_path = csvs_out_path
        self._messages = []

        # Create a temp dir to store the pose CSVs per class
        self._csvs_out_folder_per_class = tempfile.mkdtemp()

        # Get list of pose classes and print image statistics
        self._pose_class_names = sorted([
            n for n in os.listdir(self._images_in_folder)
            if not n.startswith('.')
        ])

    def process(self, per_pose_class_limit=None, detection_threshold=0.1):
        """Preprocesses images in the given folder.
    Args:
      per_pose_class_limit: Number of images to load. As preprocessing usually
        takes time, this parameter can be specified to make the reduce of the
        dataset for testing.
      detection_threshold: Only keep images with all landmark confidence score
        above this threshold.
    """
        # Loop through the classes and preprocess its images
        for pose_class_name in self._pose_class_names:
            print('Preprocessing', pose_class_name, file=sys.stderr)

            # Paths for the pose class.
            images_in_folder = os.path.join(self._images_in_folder,
                                            pose_class_name)
            images_out_folder = os.path.join(self._images_out_folder,
                                             pose_class_name)
            csv_out_path = os.path.join(self._csvs_out_folder_per_class,
                                        pose_class_name + '.csv')
            if not os.path.exists(images_out_folder):
                os.makedirs(images_out_folder)

            # Detect landmarks in each image and write it to a CSV file
            with open(csv_out_path, 'w') as csv_out_file:
                csv_out_writer = csv.writer(csv_out_file,
                                            delimiter=',',
                                            quoting=csv.QUOTE_MINIMAL)
                # Get list of images
                image_names = sorted([
                    n for n in os.listdir(images_in_folder)
                    if not n.startswith('.')
                ])
                if per_pose_class_limit is not None:
                    image_names = image_names[:per_pose_class_limit]

                valid_image_count = 0

                # Detect pose landmarks from each image
                for image_name in tqdm.tqdm(image_names):
                    image_path = os.path.join(images_in_folder, image_name)

                    try:
                        image = tf.io.read_file(image_path)
                        image = tf.io.decode_jpeg(image)
                    except:
                        self._messages.append('Skipped ' + image_path +
                                              '. Invalid image.')
                        continue
                    else:
                        image = tf.io.read_file(image_path)
                        image = tf.io.decode_jpeg(image)
                        image_height, image_width, channel = image.shape

                    # Skip images that isn't RGB because Movenet requires RGB images
                    if channel != 3:
                        self._messages.append('Skipped ' + image_path +
                                              '. Image isn\'t in RGB format.')
                        continue
                    person = detect(image)

                    # Save landmarks if all landmarks were detected
                    min_landmark_score = min(
                        [keypoint.score for keypoint in person.keypoints])
                    should_keep_image = min_landmark_score >= detection_threshold
                    if not should_keep_image:
                        self._messages.append(
                            'Skipped ' + image_path +
                            '. No pose was confidentlly detected.')
                        continue

                    valid_image_count += 1

                    # Draw the prediction result on top of the image for debugging later
                    output_overlay = draw_prediction_on_image(
                        image.numpy().astype(np.uint8),
                        person,
                        close_figure=True,
                        keep_input_size=True)

                    # Write detection result into an image file
                    output_frame = cv2.cvtColor(output_overlay,
                                                cv2.COLOR_RGB2BGR)
                    cv2.imwrite(os.path.join(images_out_folder, image_name),
                                output_frame)

                    # Get landmarks and scale it to the same size as the input image
                    pose_landmarks = np.array([[
                        keypoint.coordinate.x, keypoint.coordinate.y,
                        keypoint.score
                    ] for keypoint in person.keypoints],
                                              dtype=np.float32)

                    # Write the landmark coordinates to its per-class CSV file
                    # numpy版本1.24.1时将np.str修改为np.str_才能正常运行
                    coordinates = pose_landmarks.flatten().astype(
                        np.str_).tolist()
                    csv_out_writer.writerow([image_name] + coordinates)

                if not valid_image_count:
                    raise RuntimeError(
                        'No valid images found for the "{}" class.'.format(
                            pose_class_name))

        # Print the error message collected during preprocessing.
        print('\n'.join(self._messages))

        # Combine all per-class CSVs into a single output file
        all_landmarks_df = self._all_landmarks_as_dataframe()
        all_landmarks_df.to_csv(self._csvs_out_path, index=False)

    def class_names(self):
        """List of classes found in the training dataset."""
        return self._pose_class_names

    def _all_landmarks_as_dataframe(self):
        """Merge all per-class CSVs into a single dataframe."""
        total_df = None
        for class_index, class_name in enumerate(self._pose_class_names):
            csv_out_path = os.path.join(self._csvs_out_folder_per_class,
                                        class_name + '.csv')
            per_class_df = pd.read_csv(csv_out_path, header=None)

            # Add the labels
            per_class_df['class_no'] = [class_index] * len(per_class_df)
            per_class_df['class_name'] = [class_name] * len(per_class_df)

            # Append the folder name to the filename column (first column)
            per_class_df[per_class_df.columns[0]] = (
                os.path.join(class_name, '') +
                per_class_df[per_class_df.columns[0]].astype(str))

            if total_df is None:
                # For the first class, assign its data to the total dataframe
                total_df = per_class_df
            else:
                # Concatenate each class's data into the total dataframe
                total_df = pd.concat([total_df, per_class_df], axis=0)

        list_name = [[
            bodypart.name + '_x', bodypart.name + '_y',
            bodypart.name + '_score'
        ] for bodypart in BodyPart]
        header_name = []
        for columns_name in list_name:
            header_name += columns_name
        header_name = ['file_name'] + header_name
        header_map = {
            total_df.columns[i]: header_name[i]
            for i in range(len(header_name))
        }

        total_df.rename(header_map, axis=1, inplace=True)

        return total_df

# %%
# print(np.__version___)

# %%
#@title (Optional) Code snippet to try out the Movenet pose estimation logic

#@markdown You can download an image from the internet, run the pose estimation logic on it and plot the detected landmarks on top of the input image.

#@markdown *Note: This code snippet is also useful for debugging when you encounter an image with bad pose classification accuracy. You can run pose estimation on the image and see if the detected landmarks look correct or not before investigating the pose classification logic.*

# test_image_url = "https://cdn.pixabay.com/photo/2017/03/03/17/30/yoga-2114512_960_720.jpg" #@param {type:"string"}
# !wget -O /tmp/image.jpeg {test_image_url}

#if len(test_image_url):
image_bad = tf.io.read_file(
    '/Users/fuugamo/Documents/CV/rfa_-project/main/pose_data/train/plank_standard/plank_standard1.jpg')
image_bad = tf.io.decode_jpeg(image_bad)
person = detect(image_bad)
_ = draw_prediction_on_image(image_bad.numpy(),
                             person,
                             crop_region=None,
                             close_figure=False,
                             keep_input_size=True)

# %%
# 画一个正确坐姿的图片，和错误坐姿进行对比示意
image_good = tf.io.read_file(
    '/Users/fuugamo/Documents/CV/rfa_-project/main/pose_data/test/plank_standard/plank_standard108.jpg'
)
image_good = tf.io.decode_jpeg(image_good)
person = detect(image_good)
_ = draw_prediction_on_image(image_good.numpy(),
                             person,
                             crop_region=None,
                             close_figure=False,
                             keep_input_size=True)

# %% [markdown]
# 以上是准备工作，接下来开始正式处理图片。
# ## Part 1: Preprocess the input images
#
# Because the input for our pose classifier is the *output* landmarks from the MoveNet model, we need to generate our training dataset by running labeled images through MoveNet and then capturing all the landmark data and ground truth labels into a CSV file.
#
# The dataset we've provided for this tutorial is a CG-generated yoga pose dataset. It contains images of multiple CG-generated models doing 5 different yoga poses. The directory is already split into a `train` dataset and a `test` dataset.
#
# So in this section, we'll download the yoga dataset and run it through MoveNet so we can capture all the landmarks into a CSV file... **However, it takes about 15 minutes to feed our yoga dataset to MoveNet and generate this CSV file**. So as an alternative, you can download a pre-existing CSV file for the yoga dataset by setting `is_skip_step_1` parameter below to **True**. That way, you'll skip this step and instead download the same CSV file that will be created in this preprocessing step.
#
# On the other hand, if you want to train the pose classifier with your own image dataset, you need to upload your images and run this preprocessing step (leave `is_skip_step_1` **False**)—follow the instructions below to upload your own pose dataset.

# %%
is_skip_step_1 = False  #@param ["False", "True"] {type:"raw"}

# %% [markdown]
# ### (Optional) Upload your own pose dataset

# %%
use_custom_dataset = True  #@param ["False", "True"] {type:"raw"}

dataset_is_split = True  #@param ["False", "True"] {type:"raw"}

# %% [markdown]
# If you want to train the pose classifier with your own labeled poses (they can be any poses, not just yoga poses), follow these steps:
#
# 1. Set the above `use_custom_dataset` option to **True**.
#
# 2. Prepare an archive file (ZIP, TAR, or other) that includes a folder with your images dataset. The folder must include sorted images of your poses as follows.
#
#   If you've already split your dataset into train and test sets, then set `dataset_is_split` to **True**. That is, your images folder must include "train" and "test" directories like this:
#
#     ```
#     yoga_poses/
#     |__ train/
#         |__ downdog/
#             |______ 00000128.jpg
#             |______ ...
#     |__ test/
#         |__ downdog/
#             |______ 00000181.jpg
#             |______ ...
#     ```
#
#     Or, if your dataset is NOT split yet, then set
#     `dataset_is_split` to **False** and we'll split it up based
#     on a specified split fraction. That is, your uploaded images
#     folder should look like this:
#
#     ```
#     yoga_poses/
#     |__ downdog/
#         |______ 00000128.jpg
#         |______ 00000181.jpg
#         |______ ...
#     |__ goddess/
#         |______ 00000243.jpg
#         |______ 00000306.jpg
#         |______ ...
#     ```
# 3. Click the **Files** tab on the left (folder icon) and then click **Upload to session storage** (file icon).
# 4. Select your archive file and wait until it finishes uploading before you proceed.
# 5. Edit the following code block to specify the name of your archive file and images directory. (By default, we expect a ZIP file, so you'll need to also modify that part if your archive is another format.)
# 6. Now run the rest of the notebook.

# %%
#@markdown Be sure you run this cell. It's hiding the `split_into_train_test()` function that's called in the next code block.

import os
import random
import shutil


def split_into_train_test(images_origin, images_dest, test_split):
    """Splits a directory of sorted images into training and test sets.

  Args:
    images_origin: Path to the directory with your images. This directory
      must include subdirectories for each of your labeled classes. For example:
      yoga_poses/
      |__ downdog/
          |______ 00000128.jpg
          |______ 00000181.jpg
          |______ ...
      |__ goddess/
          |______ 00000243.jpg
          |______ 00000306.jpg
          |______ ...
      ...
    images_dest: Path to a directory where you want the split dataset to be
      saved. The results looks like this:
      split_yoga_poses/
      |__ train/
          |__ downdog/
              |______ 00000128.jpg
              |______ ...
      |__ test/
          |__ downdog/
              |______ 00000181.jpg
              |______ ...
    test_split: Fraction of data to reserve for test (float between 0 and 1).
  """
    _, dirs, _ = next(os.walk(images_origin))

    TRAIN_DIR = os.path.join(images_dest, 'train')
    TEST_DIR = os.path.join(images_dest, 'test')
    os.makedirs(TRAIN_DIR, exist_ok=True)
    os.makedirs(TEST_DIR, exist_ok=True)

    for dir in dirs:
        # Get all filenames for this dir, filtered by filetype
        filenames = os.listdir(os.path.join(images_origin, dir))
        filenames = [
            os.path.join(images_origin, dir, f) for f in filenames
            if (f.endswith('.png') or f.endswith('.jpg') or f.endswith('.jpeg')
                or f.endswith('.bmp'))
        ]
        # Shuffle the files, deterministically
        filenames.sort()
        random.seed(42)
        random.shuffle(filenames)
        # Divide them into train/test dirs
        os.makedirs(os.path.join(TEST_DIR, dir), exist_ok=True)
        os.makedirs(os.path.join(TRAIN_DIR, dir), exist_ok=True)
        test_count = int(len(filenames) * test_split)
        for i, file in enumerate(filenames):
            if i < test_count:
                destination = os.path.join(TEST_DIR, dir,
                                           os.path.split(file)[1])
            else:
                destination = os.path.join(TRAIN_DIR, dir,
                                           os.path.split(file)[1])
            shutil.copyfile(file, destination)
        print(
            f'Moved {test_count} of {len(filenames)} from class "{dir}" into test.'
        )
    print(f'Your split dataset is in "{images_dest}"')

# %%
if use_custom_dataset:
    # ATTENTION:
    # You must edit these two lines to match your archive and images folder name:
    # !tar -xf YOUR_DATASET_ARCHIVE_NAME.tar
    # !unzip -q YOUR_DATASET_ARCHIVE_NAME.zip
    dataset_in = 'pose_data'

    # You can leave the rest alone:
    if not os.path.isdir(dataset_in):
        raise Exception("dataset_in is not a valid directory")
    if dataset_is_split:
        IMAGES_ROOT = dataset_in
    else:
        dataset_out = 'split_' + dataset_in
        split_into_train_test(dataset_in, dataset_out, test_split=0.2)
        IMAGES_ROOT = dataset_out

# %% [markdown]
# **Note:** If you're using `split_into_train_test()` to split the dataset, it expects all images to be PNG, JPEG, or BMP—it ignores other file types.

# %% [markdown]
# ### Download the yoga dataset

# %%
if not is_skip_step_1 and not use_custom_dataset:
  # !wget -O yoga_poses.zip http://download.tensorflow.org/data/pose_classification/yoga_poses.zip
  # !unzip -q yoga_poses.zip -d yoga_cg
  IMAGES_ROOT = "yoga_cg"

# %% [markdown]
# ### Preprocess the `TRAIN` dataset

# %%
if not is_skip_step_1:
    images_in_train_folder = os.path.join(IMAGES_ROOT, 'train')
    images_out_train_folder = 'poses_images_out_train'
    csvs_out_train_path = 'train_data.csv'

    preprocessor = MoveNetPreprocessor(
        images_in_folder=images_in_train_folder,
        images_out_folder=images_out_train_folder,                                                                                                                    
        csvs_out_path=csvs_out_train_path,
    )

    preprocessor.process(per_pose_class_limit=None)
# Out:
# Preprocessing plank_HighHead
#   0%|          | 0/468 [00:00<?, ?it/s]
# 100%|██████████| 468/468 [00:56<00:00,  8.33it/s]
# Preprocessing plank_HighHip
# 100%|██████████| 463/463 [00:48<00:00,  9.50it/s]
# Preprocessing plank_standard
# 100%|█████████▉| 476/477 [00:53<00:00, 10.02it/s]/Users/fuugamo/miniconda3/envs/tf/lib/python3.10/site-packages/numpy/lib/function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /Users/fuugamo/miniconda3/envs/tf/lib/python3.10/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 477/477 [00:53<00:00,  8.94it/s]
# Preprocessing squat_forerake
# 100%|██████████| 383/383 [00:48<00:00,  7.94it/s]
# Preprocessing squat_shallow
# 100%|██████████| 359/359 [00:44<00:00,  8.04it/s]
# Preprocessing squat_standard
# 100%|██████████| 349/349 [00:44<00:00,  7.93it/s]
# Preprocessing stand
# 100%|██████████| 102/102 [00:12<00:00,  7.87it/s]
# Skipped pose_data/train/plank_HighHead/plank_HighHead102.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead104.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead107.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead113.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead114.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead115.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead118.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead121.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead122.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead128.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead129.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead130.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead274.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead281.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead282.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead283.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead284.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead285.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead287.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead290.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead291.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead294.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead296.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead298.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead299.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead305.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead306.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead315.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead460.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead461.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead464.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead465.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead466.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead467.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead471.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead472.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead474.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead476.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead486.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead488.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead489.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead91.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead93.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead94.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHead/plank_HighHead98.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip119.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip175.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip178.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip184.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip195.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip256.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip259.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip260.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip261.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip262.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip264.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip265.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip267.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip268.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip269.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip270.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip271.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip272.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip273.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip274.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip275.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip276.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip277.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip280.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip283.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip284.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip285.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip286.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip287.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip289.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip290.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip291.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip292.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip298.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip302.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip304.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip305.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip309.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip437.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip441.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip442.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip443.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip445.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip446.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip457.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip458.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip466.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip467.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip469.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip470.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip471.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip472.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip473.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip475.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip476.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip477.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip478.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip479.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip487.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip67.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip68.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip72.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip78.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip79.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip80.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip81.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip83.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip84.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip85.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip86.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip88.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip89.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip91.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip93.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip94.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_HighHip/plank_HighHip99.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard100.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard101.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard102.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard105.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard106.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard107.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard111.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard115.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard118.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard119.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard120.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard133.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard134.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard136.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard234.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard293.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard295.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard302.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard304.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard305.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard306.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard308.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard309.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard310.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard311.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard312.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard313.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard314.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard315.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard316.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard317.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard318.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard319.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard320.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard321.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard322.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard323.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard324.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard325.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard326.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard327.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard328.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard329.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard330.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard331.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard332.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard334.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard398.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard399.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard400.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard401.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard498.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard89.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard91.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard92.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard93.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard94.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard95.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard97.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/plank_standard/plank_standard98.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_forerake/squat_forerake_182.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_forerake/squat_forerake_237.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_forerake/squat_forerake_239.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_forerake/squat_forerake_240.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_forerake/squat_forerake_241.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_forerake/squat_forerake_273.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_forerake/squat_forerake_291.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_forerake/squat_forerake_369.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_forerake/squat_forerake_371.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_forerake/squat_forerake_372.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_forerake/squat_forerake_373.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_forerake/squat_forerake_374.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_forerake/squat_forerake_74.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_forerake/squat_forerake_75.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_shallow/squat_too_shallow (208).jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_shallow/squat_too_shallow (353).jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_shallow/squat_too_shallow (387).jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_standard/squat_standard_118.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_standard/squat_standard_127.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_standard/squat_standard_131.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_standard/squat_standard_170.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_standard/squat_standard_19.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_standard/squat_standard_20.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_standard/squat_standard_21.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_standard/squat_standard_22.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_standard/squat_standard_234.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_standard/squat_standard_235.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_standard/squat_standard_248.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_standard/squat_standard_27.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_standard/squat_standard_309.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_standard/squat_standard_323.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_standard/squat_standard_46.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_standard/squat_standard_47.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_standard/squat_standard_48.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_standard/squat_standard_49.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_standard/squat_standard_77.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/squat_standard/squat_standard_81.jpg. No pose was confidentlly detected.
# Skipped pose_data/train/stand/stand (61).jpg. No pose was confidentlly detected.
# Skipped pose_data/train/stand/stand (92).jpg. No pose was confidentlly detected.

# %% [markdown]
# ### Preprocess the `TEST` dataset

# %%
if not is_skip_step_1:
    images_in_test_folder = os.path.join(IMAGES_ROOT, 'test')
    images_out_test_folder = 'poses_images_out_test'
    csvs_out_test_path = 'test_data.csv'

    preprocessor = MoveNetPreprocessor(
        images_in_folder=images_in_test_folder,
        images_out_folder=images_out_test_folder,
        csvs_out_path=csvs_out_test_path,
    )

    preprocessor.process(per_pose_class_limit=None)
# Out:
# Preprocessing plank_HighHead
# 100%|██████████| 32/32 [00:03<00:00, 10.09it/s]
# Preprocessing plank_HighHip
# 100%|██████████| 37/37 [00:03<00:00, 10.15it/s]
# Preprocessing plank_standard
# 100%|██████████| 23/23 [00:02<00:00, 10.30it/s]
# Preprocessing squat_forerake
# 100%|██████████| 24/24 [00:02<00:00,  8.15it/s]
# Preprocessing squat_shallow
# 100%|██████████| 33/33 [00:04<00:00,  8.04it/s]
# Preprocessing squat_standard
# 100%|██████████| 21/21 [00:04<00:00,  4.70it/s]
# Preprocessing stand
# 100%|██████████| 20/20 [00:02<00:00,  7.50it/s]
# Skipped pose_data/test/plank_HighHead/plank_HighHead108.jpg. No pose was confidentlly detected.
# Skipped pose_data/test/plank_HighHead/plank_HighHead90.jpg. No pose was confidentlly detected.
# Skipped pose_data/test/plank_HighHip/plank_HighHip282.jpg. No pose was confidentlly detected.
# Skipped pose_data/test/plank_HighHip/plank_HighHip288.jpg. No pose was confidentlly detected.
# Skipped pose_data/test/plank_HighHip/plank_HighHip306.jpg. No pose was confidentlly detected.
# Skipped pose_data/test/plank_HighHip/plank_HighHip312.jpg. No pose was confidentlly detected.
# Skipped pose_data/test/plank_HighHip/plank_HighHip444.jpg. No pose was confidentlly detected.
# Skipped pose_data/test/plank_HighHip/plank_HighHip450.jpg. No pose was confidentlly detected.
# Skipped pose_data/test/plank_HighHip/plank_HighHip468.jpg. No pose was confidentlly detected.
# Skipped pose_data/test/plank_HighHip/plank_HighHip474.jpg. No pose was confidentlly detected.
# Skipped pose_data/test/plank_HighHip/plank_HighHip498.jpg. No pose was confidentlly detected.
# Skipped pose_data/test/plank_standard/plank_standard108.jpg. No pose was confidentlly detected.
# Skipped pose_data/test/plank_standard/plank_standard135.jpg. No pose was confidentlly detected.
# Skipped pose_data/test/plank_standard/plank_standard90.jpg. No pose was confidentlly detected.
# Skipped pose_data/test/plank_standard/plank_standard99.jpg. No pose was confidentlly detected.
# Skipped pose_data/test/stand/stand (114).jpg. No pose was confidentlly detected.
# Skipped pose_data/test/stand/stand (60).jpg. No pose was confidentlly detected.

# %% [markdown]
# ## Part 2: Train a pose classification model that takes the landmark coordinates as input, and output the predicted labels.
#
# You'll build a TensorFlow model that takes the landmark coordinates and predicts the pose class that the person in the input image performs. The model consists of two submodels:
#
# * Submodel 1 calculates a pose embedding (a.k.a feature vector) from the detected landmark coordinates.
# * Submodel 2 feeds pose embedding through several `Dense` layer to predict the pose class.
#
# You'll then train the model based on the dataset that were preprocessed in part 1.

# %% [markdown]
# ### (Optional) Download the preprocessed dataset if you didn't run part 1

# %%
# Download the preprocessed CSV files which are the same as the output of step 1
# if is_skip_step_1:
#   !wget -O train_data.csv http://download.tensorflow.org/data/pose_classification/yoga_train_data.csv
#   !wget -O test_data.csv http://download.tensorflow.org/data/pose_classification/yoga_test_data.csv

#   csvs_out_train_path = 'train_data.csv'
#   csvs_out_test_path = 'test_data.csv'
#   is_skipped_step_1 = True

# %% [markdown]
# ### Load the preprocessed CSVs into `TRAIN` and `TEST` datasets.

# %%
def load_pose_landmarks(csv_path):
    """Loads a CSV created by MoveNetPreprocessor.
  
  Returns:
    X: Detected landmark coordinates and scores of shape (N, 17 * 3)
    y: Ground truth labels of shape (N, label_count)
    classes: The list of all class names found in the dataset
    dataframe: The CSV loaded as a Pandas dataframe features (X) and ground
      truth labels (y) to use later to train a pose classification model.
  """

    # Load the CSV file
    dataframe = pd.read_csv(csv_path)
    df_to_process = dataframe.copy()

    # Drop the file_name columns as you don't need it during training.
    df_to_process.drop(columns=['file_name'], inplace=True)

    # Extract the list of class names
    classes = df_to_process.pop('class_name').unique()

    # Extract the labels
    y = df_to_process.pop('class_no')

    # Convert the input features and labels into the correct format for training.
    X = df_to_process.astype('float64')
    y = keras.utils.to_categorical(y)

    return X, y, classes, dataframe

# %% [markdown]
# Load and split the original `TRAIN` dataset into `TRAIN` (85% of the data) and `VALIDATE` (the remaining 15%).

# %%
# Load the train data
X, y, class_names, _ = load_pose_landmarks(csvs_out_train_path)

# Split training data (X, y) into (X_train, y_train) and (X_val, y_val)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15)

# %%
# Load the test data
X_test, y_test, _, df_test = load_pose_landmarks(csvs_out_test_path)

# %% [markdown]
# ### Define functions to convert the pose landmarks to a pose embedding (a.k.a. feature vector) for pose classification
#
# Next, convert the landmark coordinates to a feature vector by:
# 1. Moving the pose center to the origin.
# 2. Scaling the pose so that the pose size becomes 1
# 3. Flattening these coordinates into a feature vector
#
# Then use this feature vector to train a neural-network based pose classifier.

# %%
def get_center_point(landmarks, left_bodypart, right_bodypart):
    """Calculates the center point of the two given landmarks."""

    left = tf.gather(landmarks, left_bodypart.value, axis=1)
    right = tf.gather(landmarks, right_bodypart.value, axis=1)
    center = left * 0.5 + right * 0.5
    return center


def get_pose_size(landmarks, torso_size_multiplier=2.5):
    """Calculates pose size.

  It is the maximum of two values:
    * Torso size multiplied by `torso_size_multiplier`
    * Maximum distance from pose center to any pose landmark
  """
    # Hips center
    hips_center = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                   BodyPart.RIGHT_HIP)

    # Shoulders center
    shoulders_center = get_center_point(landmarks, BodyPart.LEFT_SHOULDER,
                                        BodyPart.RIGHT_SHOULDER)

    # Torso size as the minimum body size
    torso_size = tf.linalg.norm(shoulders_center - hips_center)

    # Pose center
    pose_center_new = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                       BodyPart.RIGHT_HIP)
    pose_center_new = tf.expand_dims(pose_center_new, axis=1)
    # Broadcast the pose center to the same size as the landmark vector to
    # perform substraction
    pose_center_new = tf.broadcast_to(pose_center_new,
                                      [tf.size(landmarks) // (17 * 2), 17, 2])

    # Dist to pose center
    d = tf.gather(landmarks - pose_center_new,
                  0,
                  axis=0,
                  name="dist_to_pose_center")
    # Max dist to pose center
    max_dist = tf.reduce_max(tf.linalg.norm(d, axis=0))

    # Normalize scale
    pose_size = tf.maximum(torso_size * torso_size_multiplier, max_dist)

    return pose_size


def normalize_pose_landmarks(landmarks):
    """Normalizes the landmarks translation by moving the pose center to (0,0) and
  scaling it to a constant pose size.
  """
    # Move landmarks so that the pose center becomes (0,0)
    pose_center = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                   BodyPart.RIGHT_HIP)
    pose_center = tf.expand_dims(pose_center, axis=1)
    # Broadcast the pose center to the same size as the landmark vector to perform
    # substraction
    pose_center = tf.broadcast_to(pose_center,
                                  [tf.size(landmarks) // (17 * 2), 17, 2])
    landmarks = landmarks - pose_center

    # Scale the landmarks to a constant pose size
    pose_size = get_pose_size(landmarks)
    landmarks /= pose_size

    return landmarks


def landmarks_to_embedding(landmarks_and_scores):
    """Converts the input landmarks into a pose embedding."""
    # Reshape the flat input into a matrix with shape=(17, 3)
    reshaped_inputs = keras.layers.Reshape((17, 3))(landmarks_and_scores)

    # Normalize landmarks 2D
    landmarks = normalize_pose_landmarks(reshaped_inputs[:, :, :2])

    # Flatten the normalized landmark coordinates into a vector
    embedding = keras.layers.Flatten()(landmarks)

    return embedding

# %% [markdown]
# ### Define a Keras model for pose classification
#
# Our Keras model takes the detected pose landmarks, then calculates the pose embedding and predicts the pose class.

# %%
# Define the model
inputs = tf.keras.Input(shape=(51))
embedding = landmarks_to_embedding(inputs)

layer = keras.layers.Dense(128, activation=tf.nn.relu6)(embedding)
layer = keras.layers.Dropout(0.5)(layer)
layer = keras.layers.Dense(64, activation=tf.nn.relu6)(layer)
layer = keras.layers.Dropout(0.5)(layer)
outputs = keras.layers.Dense(len(class_names), activation="softmax")(layer)

model = keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 51)]         0           []
#
#  reshape (Reshape)              (None, 17, 3)        0           ['input_1[0][0]']
#
#  tf.__operators__.getitem (Slic  (None, 17, 2)       0           ['reshape[0][0]']
#  ingOpLambda)
#
#  tf.compat.v1.gather (TFOpLambd  (None, 2)           0           ['tf.__operators__.getitem[0][0]'
#  a)                                                              ]
#
#  tf.compat.v1.gather_1 (TFOpLam  (None, 2)           0           ['tf.__operators__.getitem[0][0]'
#  bda)                                                            ]
#
#  tf.math.multiply (TFOpLambda)  (None, 2)            0           ['tf.compat.v1.gather[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 2)           0           ['tf.compat.v1.gather_1[0][0]']
#  )
#
#  tf.__operators__.add (TFOpLamb  (None, 2)           0           ['tf.math.multiply[0][0]',
#  da)                                                              'tf.math.multiply_1[0][0]']
#
#  tf.compat.v1.size (TFOpLambda)  ()                  0           ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  tf.expand_dims (TFOpLambda)    (None, 1, 2)         0           ['tf.__operators__.add[0][0]']
#
#  tf.compat.v1.floor_div (TFOpLa  ()                  0           ['tf.compat.v1.size[0][0]']
#  mbda)
#
#  tf.broadcast_to (TFOpLambda)   (None, 17, 2)        0           ['tf.expand_dims[0][0]',
#                                                                   'tf.compat.v1.floor_div[0][0]']
#
#  tf.math.subtract (TFOpLambda)  (None, 17, 2)        0           ['tf.__operators__.getitem[0][0]'
#                                                                  , 'tf.broadcast_to[0][0]']
#
#  tf.compat.v1.gather_6 (TFOpLam  (None, 2)           0           ['tf.math.subtract[0][0]']
#  bda)
#
#  tf.compat.v1.gather_7 (TFOpLam  (None, 2)           0           ['tf.math.subtract[0][0]']
#  bda)
#
#  tf.math.multiply_6 (TFOpLambda  (None, 2)           0           ['tf.compat.v1.gather_6[0][0]']
#  )
#
#  tf.math.multiply_7 (TFOpLambda  (None, 2)           0           ['tf.compat.v1.gather_7[0][0]']
#  )
#
#  tf.__operators__.add_3 (TFOpLa  (None, 2)           0           ['tf.math.multiply_6[0][0]',
#  mbda)                                                            'tf.math.multiply_7[0][0]']
#
#  tf.compat.v1.size_1 (TFOpLambd  ()                  0           ['tf.math.subtract[0][0]']
#  a)
#
#  tf.compat.v1.gather_4 (TFOpLam  (None, 2)           0           ['tf.math.subtract[0][0]']
#  bda)
#
#  tf.compat.v1.gather_5 (TFOpLam  (None, 2)           0           ['tf.math.subtract[0][0]']
#  bda)
#
#  tf.compat.v1.gather_2 (TFOpLam  (None, 2)           0           ['tf.math.subtract[0][0]']
#  bda)
#
#  tf.compat.v1.gather_3 (TFOpLam  (None, 2)           0           ['tf.math.subtract[0][0]']
#  bda)
#
#  tf.expand_dims_1 (TFOpLambda)  (None, 1, 2)         0           ['tf.__operators__.add_3[0][0]']
#
#  tf.compat.v1.floor_div_1 (TFOp  ()                  0           ['tf.compat.v1.size_1[0][0]']
#  Lambda)
#
#  tf.math.multiply_4 (TFOpLambda  (None, 2)           0           ['tf.compat.v1.gather_4[0][0]']
#  )
#
#  tf.math.multiply_5 (TFOpLambda  (None, 2)           0           ['tf.compat.v1.gather_5[0][0]']
#  )
#
#  tf.math.multiply_2 (TFOpLambda  (None, 2)           0           ['tf.compat.v1.gather_2[0][0]']
#  )
#
#  tf.math.multiply_3 (TFOpLambda  (None, 2)           0           ['tf.compat.v1.gather_3[0][0]']
#  )
#
#  tf.broadcast_to_1 (TFOpLambda)  (None, 17, 2)       0           ['tf.expand_dims_1[0][0]',
#                                                                   'tf.compat.v1.floor_div_1[0][0]'
#                                                                  ]
#
#  tf.__operators__.add_2 (TFOpLa  (None, 2)           0           ['tf.math.multiply_4[0][0]',
#  mbda)                                                            'tf.math.multiply_5[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 2)           0           ['tf.math.multiply_2[0][0]',
#  mbda)                                                            'tf.math.multiply_3[0][0]']
#
#  tf.math.subtract_2 (TFOpLambda  (None, 17, 2)       0           ['tf.math.subtract[0][0]',
#  )                                                                'tf.broadcast_to_1[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (None, 2)           0           ['tf.__operators__.add_2[0][0]',
#  )                                                                'tf.__operators__.add_1[0][0]']
#
#  tf.compat.v1.gather_8 (TFOpLam  (17, 2)             0           ['tf.math.subtract_2[0][0]']
#  bda)
#
#  tf.compat.v1.norm (TFOpLambda)  ()                  0           ['tf.math.subtract_1[0][0]']
#
#  tf.compat.v1.norm_1 (TFOpLambd  (2,)                0           ['tf.compat.v1.gather_8[0][0]']
#  a)
#
#  tf.math.multiply_8 (TFOpLambda  ()                  0           ['tf.compat.v1.norm[0][0]']
#  )
#
#  tf.math.reduce_max (TFOpLambda  ()                  0           ['tf.compat.v1.norm_1[0][0]']
#  )
#
#  tf.math.maximum (TFOpLambda)   ()                   0           ['tf.math.multiply_8[0][0]',
#                                                                   'tf.math.reduce_max[0][0]']
#
#  tf.math.truediv (TFOpLambda)   (None, 17, 2)        0           ['tf.math.subtract[0][0]',
#                                                                   'tf.math.maximum[0][0]']
#
#  flatten (Flatten)              (None, 34)           0           ['tf.math.truediv[0][0]']
#
#  dense (Dense)                  (None, 128)          4480        ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 64)           8256        ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 64)           0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 7)            455         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 13,191
# Trainable params: 13,191
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Add a checkpoint callback to store the checkpoint that has the highest
# validation accuracy.
checkpoint_path = "weights.best.hdf5"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_path,
                                             monitor='val_accuracy',
                                             verbose=1,
                                             save_best_only=True,
                                             mode='max')
# patience=20
earlystopping = keras.callbacks.EarlyStopping(monitor='val_accuracy',
                                              patience=20)

# Start training 
# epochs=200, batch_size=16
history = model.fit(X_train,
                    y_train,
                    epochs=200,
                    batch_size=16,
                    validation_data=(X_test, y_test),
                    callbacks=[checkpoint, earlystopping])
# Out:
# Epoch 1/200
# 2023-08-05 17:58:33.013578: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
#  75/127 [================>.............] - ETA: 0s - loss: 1.8459 - accuracy: 0.3367
# Epoch 1: val_accuracy improved from -inf to 0.54335, saving model to weights.best.hdf5
# 127/127 [==============================] - 1s 2ms/step - loss: 1.7126 - accuracy: 0.3623 - val_loss: 1.4235 - val_accuracy: 0.5434
# Epoch 2/200
#  83/127 [==================>...........] - ETA: 0s - loss: 1.1886 - accuracy: 0.5068
# Epoch 2: val_accuracy improved from 0.54335 to 0.64162, saving model to weights.best.hdf5
# 127/127 [==============================] - 0s 863us/step - loss: 1.1470 - accuracy: 0.5205 - val_loss: 1.0616 - val_accuracy: 0.6416
# Epoch 3/200
#  83/127 [==================>...........] - ETA: 0s - loss: 0.9821 - accuracy: 0.5572
# Epoch 3: val_accuracy did not improve from 0.64162
# 127/127 [==============================] - 0s 740us/step - loss: 0.9465 - accuracy: 0.5680 - val_loss: 0.9106 - val_accuracy: 0.5838
# Epoch 4/200
#  85/127 [===================>..........] - ETA: 0s - loss: 0.8131 - accuracy: 0.6485
# Epoch 4: val_accuracy did not improve from 0.64162
# 127/127 [==============================] - 0s 734us/step - loss: 0.8056 - accuracy: 0.6565 - val_loss: 0.7741 - val_accuracy: 0.6185
# Epoch 5/200
#  85/127 [===================>..........] - ETA: 0s - loss: 0.7355 - accuracy: 0.6934
# Epoch 5: val_accuracy did not improve from 0.64162
# 127/127 [==============================] - 0s 737us/step - loss: 0.7041 - accuracy: 0.7049 - val_loss: 0.7063 - val_accuracy: 0.6358
# Epoch 6/200
#  84/127 [==================>...........] - ETA: 0s - loss: 0.6078 - accuracy: 0.7500
# Epoch 6: val_accuracy improved from 0.64162 to 0.65896, saving model to weights.best.hdf5
# 127/127 [==============================] - 0s 876us/step - loss: 0.5982 - accuracy: 0.7533 - val_loss: 0.6230 - val_accuracy: 0.6590
# Epoch 7/200
#  85/127 [===================>..........] - ETA: 0s - loss: 0.5438 - accuracy: 0.7787
# Epoch 7: val_accuracy improved from 0.65896 to 0.73410, saving model to weights.best.hdf5
# 127/127 [==============================] - 0s 850us/step - loss: 0.5394 - accuracy: 0.7889 - val_loss: 0.5973 - val_accuracy: 0.7341
# Epoch 8/200
#  86/127 [===================>..........] - ETA: 0s - loss: 0.5012 - accuracy: 0.8103
# Epoch 8: val_accuracy improved from 0.73410 to 0.78035, saving model to weights.best.hdf5
# 127/127 [==============================] - 0s 831us/step - loss: 0.4862 - accuracy: 0.8191 - val_loss: 0.5148 - val_accuracy: 0.7803
# Epoch 9/200
#  91/127 [====================>.........] - ETA: 0s - loss: 0.4403 - accuracy: 0.8297
# Epoch 9: val_accuracy did not improve from 0.78035
# 127/127 [==============================] - 0s 698us/step - loss: 0.4440 - accuracy: 0.8225 - val_loss: 0.4872 - val_accuracy: 0.7630
# Epoch 10/200
#  86/127 [===================>..........] - ETA: 0s - loss: 0.4006 - accuracy: 0.8387
# Epoch 10: val_accuracy improved from 0.78035 to 0.83815, saving model to weights.best.hdf5
# 127/127 [==============================] - 0s 856us/step - loss: 0.4057 - accuracy: 0.8374 - val_loss: 0.4569 - val_accuracy: 0.8382
# Epoch 11/200
#  89/127 [====================>.........] - ETA: 0s - loss: 0.3896 - accuracy: 0.8497
# Epoch 11: val_accuracy did not improve from 0.83815
# 127/127 [==============================] - 0s 704us/step - loss: 0.3809 - accuracy: 0.8537 - val_loss: 0.4781 - val_accuracy: 0.8324
# Epoch 12/200
#  86/127 [===================>..........] - ETA: 0s - loss: 0.3508 - accuracy: 0.8823
# Epoch 12: val_accuracy did not improve from 0.83815
# 127/127 [==============================] - 0s 715us/step - loss: 0.3501 - accuracy: 0.8764 - val_loss: 0.4664 - val_accuracy: 0.8208
# Epoch 13/200
#  88/127 [===================>..........] - ETA: 0s - loss: 0.3211 - accuracy: 0.8729
# Epoch 13: val_accuracy did not improve from 0.83815
# 127/127 [==============================] - 0s 707us/step - loss: 0.3227 - accuracy: 0.8735 - val_loss: 0.4959 - val_accuracy: 0.8266
# Epoch 14/200
#  83/127 [==================>...........] - ETA: 0s - loss: 0.3265 - accuracy: 0.8742
# Epoch 14: val_accuracy did not improve from 0.83815
# 127/127 [==============================] - 0s 723us/step - loss: 0.3113 - accuracy: 0.8828 - val_loss: 0.4877 - val_accuracy: 0.8208
# Epoch 15/200
#  91/127 [====================>.........] - ETA: 0s - loss: 0.2918 - accuracy: 0.9004
# Epoch 15: val_accuracy did not improve from 0.83815
# 127/127 [==============================] - 0s 696us/step - loss: 0.2934 - accuracy: 0.8987 - val_loss: 0.4027 - val_accuracy: 0.8324
# Epoch 16/200
#  84/127 [==================>...........] - ETA: 0s - loss: 0.2823 - accuracy: 0.8914
# Epoch 16: val_accuracy did not improve from 0.83815
# 127/127 [==============================] - 0s 735us/step - loss: 0.2876 - accuracy: 0.8972 - val_loss: 0.4701 - val_accuracy: 0.8208
# Epoch 17/200
#  87/127 [===================>..........] - ETA: 0s - loss: 0.2834 - accuracy: 0.9131
# Epoch 17: val_accuracy improved from 0.83815 to 0.84971, saving model to weights.best.hdf5
# 127/127 [==============================] - 0s 811us/step - loss: 0.2672 - accuracy: 0.9204 - val_loss: 0.3843 - val_accuracy: 0.8497
# Epoch 18/200
#  88/127 [===================>..........] - ETA: 0s - loss: 0.2602 - accuracy: 0.9119
# Epoch 18: val_accuracy did not improve from 0.84971
# 127/127 [==============================] - 0s 726us/step - loss: 0.2543 - accuracy: 0.9174 - val_loss: 0.4132 - val_accuracy: 0.8382
# Epoch 19/200
#  92/127 [====================>.........] - ETA: 0s - loss: 0.2341 - accuracy: 0.9314
# Epoch 19: val_accuracy improved from 0.84971 to 0.85549, saving model to weights.best.hdf5
# 127/127 [==============================] - 0s 799us/step - loss: 0.2299 - accuracy: 0.9303 - val_loss: 0.4072 - val_accuracy: 0.8555
# Epoch 20/200
#  89/127 [====================>.........] - ETA: 0s - loss: 0.2160 - accuracy: 0.9291
# Epoch 20: val_accuracy did not improve from 0.85549
# 127/127 [==============================] - 0s 708us/step - loss: 0.2160 - accuracy: 0.9288 - val_loss: 0.4671 - val_accuracy: 0.8382
# Epoch 21/200
#  90/127 [====================>.........] - ETA: 0s - loss: 0.2126 - accuracy: 0.9347
# Epoch 21: val_accuracy did not improve from 0.85549
# 127/127 [==============================] - 0s 699us/step - loss: 0.2090 - accuracy: 0.9367 - val_loss: 0.4259 - val_accuracy: 0.8439
# Epoch 22/200
#  91/127 [====================>.........] - ETA: 0s - loss: 0.2146 - accuracy: 0.9354
# Epoch 22: val_accuracy did not improve from 0.85549
# 127/127 [==============================] - 0s 698us/step - loss: 0.2131 - accuracy: 0.9343 - val_loss: 0.4281 - val_accuracy: 0.8497
# Epoch 23/200
#  88/127 [===================>..........] - ETA: 0s - loss: 0.1862 - accuracy: 0.9361
# Epoch 23: val_accuracy did not improve from 0.85549
# 127/127 [==============================] - 0s 716us/step - loss: 0.1926 - accuracy: 0.9377 - val_loss: 0.4023 - val_accuracy: 0.8324
# Epoch 24/200
#  88/127 [===================>..........] - ETA: 0s - loss: 0.1795 - accuracy: 0.9439
# Epoch 24: val_accuracy improved from 0.85549 to 0.86127, saving model to weights.best.hdf5
# 127/127 [==============================] - 0s 821us/step - loss: 0.1916 - accuracy: 0.9397 - val_loss: 0.3237 - val_accuracy: 0.8613
# Epoch 25/200
#  88/127 [===================>..........] - ETA: 0s - loss: 0.2037 - accuracy: 0.9389
# Epoch 25: val_accuracy did not improve from 0.86127
# 127/127 [==============================] - 0s 702us/step - loss: 0.1937 - accuracy: 0.9407 - val_loss: 0.4179 - val_accuracy: 0.8324
# Epoch 26/200
#  89/127 [====================>.........] - ETA: 0s - loss: 0.1739 - accuracy: 0.9515
# Epoch 26: val_accuracy did not improve from 0.86127
# 127/127 [==============================] - 0s 696us/step - loss: 0.1801 - accuracy: 0.9456 - val_loss: 0.3957 - val_accuracy: 0.8439
# Epoch 27/200
#  87/127 [===================>..........] - ETA: 0s - loss: 0.1772 - accuracy: 0.9490
# Epoch 27: val_accuracy did not improve from 0.86127
# 127/127 [==============================] - 0s 703us/step - loss: 0.1756 - accuracy: 0.9476 - val_loss: 0.3789 - val_accuracy: 0.8613
# Epoch 28/200
#  92/127 [====================>.........] - ETA: 0s - loss: 0.1530 - accuracy: 0.9572
# Epoch 28: val_accuracy did not improve from 0.86127
# 127/127 [==============================] - 0s 679us/step - loss: 0.1574 - accuracy: 0.9565 - val_loss: 0.4084 - val_accuracy: 0.8613
# Epoch 29/200
#  88/127 [===================>..........] - ETA: 0s - loss: 0.1583 - accuracy: 0.9574
# Epoch 29: val_accuracy did not improve from 0.86127
# 127/127 [==============================] - 0s 708us/step - loss: 0.1595 - accuracy: 0.9540 - val_loss: 0.4375 - val_accuracy: 0.8439
# Epoch 30/200
#  90/127 [====================>.........] - ETA: 0s - loss: 0.1513 - accuracy: 0.9583
# Epoch 30: val_accuracy did not improve from 0.86127
# 127/127 [==============================] - 0s 704us/step - loss: 0.1505 - accuracy: 0.9550 - val_loss: 0.4919 - val_accuracy: 0.8439
# Epoch 31/200
#  90/127 [====================>.........] - ETA: 0s - loss: 0.1442 - accuracy: 0.9569
# Epoch 31: val_accuracy did not improve from 0.86127
# 127/127 [==============================] - 0s 702us/step - loss: 0.1457 - accuracy: 0.9555 - val_loss: 0.4403 - val_accuracy: 0.8555
# Epoch 32/200
#  92/127 [====================>.........] - ETA: 0s - loss: 0.1320 - accuracy: 0.9599
# Epoch 32: val_accuracy did not improve from 0.86127
# 127/127 [==============================] - 0s 684us/step - loss: 0.1437 - accuracy: 0.9585 - val_loss: 0.4335 - val_accuracy: 0.8613
# Epoch 33/200
#  91/127 [====================>.........] - ETA: 0s - loss: 0.1434 - accuracy: 0.9622
# Epoch 33: val_accuracy improved from 0.86127 to 0.91908, saving model to weights.best.hdf5
# 127/127 [==============================] - 0s 802us/step - loss: 0.1355 - accuracy: 0.9639 - val_loss: 0.2776 - val_accuracy: 0.9191
# Epoch 34/200
#  93/127 [====================>.........] - ETA: 0s - loss: 0.1288 - accuracy: 0.9556
# Epoch 34: val_accuracy did not improve from 0.91908
# 127/127 [==============================] - 0s 744us/step - loss: 0.1411 - accuracy: 0.9521 - val_loss: 0.3957 - val_accuracy: 0.8728
# Epoch 35/200
#  88/127 [===================>..........] - ETA: 0s - loss: 0.1378 - accuracy: 0.9616
# Epoch 35: val_accuracy did not improve from 0.91908
# 127/127 [==============================] - 0s 724us/step - loss: 0.1327 - accuracy: 0.9605 - val_loss: 0.4195 - val_accuracy: 0.8671
# Epoch 36/200
#  90/127 [====================>.........] - ETA: 0s - loss: 0.1212 - accuracy: 0.9646
# Epoch 36: val_accuracy did not improve from 0.91908
# 127/127 [==============================] - 0s 697us/step - loss: 0.1167 - accuracy: 0.9664 - val_loss: 0.4690 - val_accuracy: 0.8555
# Epoch 37/200
#  93/127 [====================>.........] - ETA: 0s - loss: 0.1296 - accuracy: 0.9657
# Epoch 37: val_accuracy did not improve from 0.91908
# 127/127 [==============================] - 0s 681us/step - loss: 0.1258 - accuracy: 0.9664 - val_loss: 0.3708 - val_accuracy: 0.8555
# Epoch 38/200
#  87/127 [===================>..........] - ETA: 0s - loss: 0.1097 - accuracy: 0.9691
# Epoch 38: val_accuracy did not improve from 0.91908
# 127/127 [==============================] - 0s 719us/step - loss: 0.1381 - accuracy: 0.9624 - val_loss: 0.3600 - val_accuracy: 0.8728
# Epoch 39/200
#  88/127 [===================>..........] - ETA: 0s - loss: 0.1182 - accuracy: 0.9673
# Epoch 39: val_accuracy did not improve from 0.91908
# 127/127 [==============================] - 0s 728us/step - loss: 0.1198 - accuracy: 0.9654 - val_loss: 0.4295 - val_accuracy: 0.8497
# Epoch 40/200
#  84/127 [==================>...........] - ETA: 0s - loss: 0.0984 - accuracy: 0.9680
# Epoch 40: val_accuracy did not improve from 0.91908
# 127/127 [==============================] - 0s 740us/step - loss: 0.1208 - accuracy: 0.9629 - val_loss: 0.3495 - val_accuracy: 0.9017
# Epoch 41/200
#  91/127 [====================>.........] - ETA: 0s - loss: 0.1082 - accuracy: 0.9663
# Epoch 41: val_accuracy did not improve from 0.91908
# 127/127 [==============================] - 0s 691us/step - loss: 0.1044 - accuracy: 0.9689 - val_loss: 0.4410 - val_accuracy: 0.8728
# Epoch 42/200
#  86/127 [===================>..........] - ETA: 0s - loss: 0.1011 - accuracy: 0.9709
# Epoch 42: val_accuracy did not improve from 0.91908
# 127/127 [==============================] - 0s 720us/step - loss: 0.1069 - accuracy: 0.9689 - val_loss: 0.4471 - val_accuracy: 0.8613
# Epoch 43/200
#  90/127 [====================>.........] - ETA: 0s - loss: 0.1106 - accuracy: 0.9632
# Epoch 43: val_accuracy did not improve from 0.91908
# 127/127 [==============================] - 0s 700us/step - loss: 0.1091 - accuracy: 0.9654 - val_loss: 0.3933 - val_accuracy: 0.8844
# Epoch 44/200
#  90/127 [====================>.........] - ETA: 0s - loss: 0.1135 - accuracy: 0.9688
# Epoch 44: val_accuracy improved from 0.91908 to 0.93642, saving model to weights.best.hdf5
# 127/127 [==============================] - 0s 830us/step - loss: 0.1162 - accuracy: 0.9689 - val_loss: 0.2549 - val_accuracy: 0.9364
# Epoch 45/200
#  88/127 [===================>..........] - ETA: 0s - loss: 0.1072 - accuracy: 0.9659
# Epoch 45: val_accuracy did not improve from 0.93642
# 127/127 [==============================] - 0s 709us/step - loss: 0.1148 - accuracy: 0.9624 - val_loss: 0.3910 - val_accuracy: 0.9017
# Epoch 46/200
#  89/127 [====================>.........] - ETA: 0s - loss: 0.1110 - accuracy: 0.9719
# Epoch 46: val_accuracy did not improve from 0.93642
# 127/127 [==============================] - 0s 720us/step - loss: 0.1040 - accuracy: 0.9753 - val_loss: 0.3918 - val_accuracy: 0.8844
# Epoch 47/200
#  87/127 [===================>..........] - ETA: 0s - loss: 0.1059 - accuracy: 0.9648
# Epoch 47: val_accuracy did not improve from 0.93642
# 127/127 [==============================] - 0s 735us/step - loss: 0.1108 - accuracy: 0.9639 - val_loss: 0.5257 - val_accuracy: 0.8555
# Epoch 48/200
#  88/127 [===================>..........] - ETA: 0s - loss: 0.0959 - accuracy: 0.9723
# Epoch 48: val_accuracy did not improve from 0.93642
# 127/127 [==============================] - 0s 712us/step - loss: 0.0951 - accuracy: 0.9713 - val_loss: 0.4606 - val_accuracy: 0.8613
# Epoch 49/200
#  84/127 [==================>...........] - ETA: 0s - loss: 0.0955 - accuracy: 0.9725
# Epoch 49: val_accuracy did not improve from 0.93642
# 127/127 [==============================] - 0s 740us/step - loss: 0.0913 - accuracy: 0.9738 - val_loss: 0.4620 - val_accuracy: 0.8671
# Epoch 50/200
#  87/127 [===================>..........] - ETA: 0s - loss: 0.0896 - accuracy: 0.9705
# Epoch 50: val_accuracy did not improve from 0.93642
# 127/127 [==============================] - 0s 727us/step - loss: 0.0919 - accuracy: 0.9718 - val_loss: 0.3899 - val_accuracy: 0.9017
# Epoch 51/200
#  91/127 [====================>.........] - ETA: 0s - loss: 0.0909 - accuracy: 0.9773
# Epoch 51: val_accuracy did not improve from 0.93642
# 127/127 [==============================] - 0s 692us/step - loss: 0.0899 - accuracy: 0.9753 - val_loss: 0.2638 - val_accuracy: 0.9249
# Epoch 52/200
#  91/127 [====================>.........] - ETA: 0s - loss: 0.1016 - accuracy: 0.9760
# Epoch 52: val_accuracy did not improve from 0.93642
# 127/127 [==============================] - 0s 719us/step - loss: 0.0964 - accuracy: 0.9748 - val_loss: 0.3628 - val_accuracy: 0.9133
# Epoch 53/200
#  91/127 [====================>.........] - ETA: 0s - loss: 0.0814 - accuracy: 0.9760
# Epoch 53: val_accuracy did not improve from 0.93642
# 127/127 [==============================] - 0s 694us/step - loss: 0.0825 - accuracy: 0.9768 - val_loss: 0.3984 - val_accuracy: 0.8902
# Epoch 54/200
#  89/127 [====================>.........] - ETA: 0s - loss: 0.0974 - accuracy: 0.9747
# Epoch 54: val_accuracy did not improve from 0.93642
# 127/127 [==============================] - 0s 711us/step - loss: 0.1003 - accuracy: 0.9748 - val_loss: 0.3921 - val_accuracy: 0.8960
# Epoch 55/200
#  88/127 [===================>..........] - ETA: 0s - loss: 0.0826 - accuracy: 0.9759
# Epoch 55: val_accuracy did not improve from 0.93642
# 127/127 [==============================] - 0s 698us/step - loss: 0.0972 - accuracy: 0.9728 - val_loss: 0.3360 - val_accuracy: 0.9075
# Epoch 56/200
#  90/127 [====================>.........] - ETA: 0s - loss: 0.0738 - accuracy: 0.9792
# Epoch 56: val_accuracy did not improve from 0.93642
# 127/127 [==============================] - 0s 694us/step - loss: 0.0832 - accuracy: 0.9773 - val_loss: 0.3200 - val_accuracy: 0.9075
# Epoch 57/200
#  89/127 [====================>.........] - ETA: 0s - loss: 0.0898 - accuracy: 0.9768
# Epoch 57: val_accuracy did not improve from 0.93642
# 127/127 [==============================] - 0s 699us/step - loss: 0.0847 - accuracy: 0.9773 - val_loss: 0.3572 - val_accuracy: 0.9075
# Epoch 58/200
#  90/127 [====================>.........] - ETA: 0s - loss: 0.0839 - accuracy: 0.9708
# Epoch 58: val_accuracy did not improve from 0.93642
# 127/127 [==============================] - 0s 700us/step - loss: 0.0836 - accuracy: 0.9728 - val_loss: 0.4129 - val_accuracy: 0.8844
# Epoch 59/200
#  91/127 [====================>.........] - ETA: 0s - loss: 0.0996 - accuracy: 0.9794
# Epoch 59: val_accuracy did not improve from 0.93642
# 127/127 [==============================] - 0s 702us/step - loss: 0.0923 - accuracy: 0.9792 - val_loss: 0.3398 - val_accuracy: 0.9249
# Epoch 60/200
#  92/127 [====================>.........] - ETA: 0s - loss: 0.0768 - accuracy: 0.9776
# Epoch 60: val_accuracy did not improve from 0.93642
# 127/127 [==============================] - 0s 690us/step - loss: 0.0768 - accuracy: 0.9787 - val_loss: 0.3155 - val_accuracy: 0.9191
# Epoch 61/200
#  90/127 [====================>.........] - ETA: 0s - loss: 0.0807 - accuracy: 0.9771
# Epoch 61: val_accuracy did not improve from 0.93642
# 127/127 [==============================] - 0s 701us/step - loss: 0.0777 - accuracy: 0.9763 - val_loss: 0.3931 - val_accuracy: 0.8960
# Epoch 62/200
#  92/127 [====================>.........] - ETA: 0s - loss: 0.0693 - accuracy: 0.9823
# Epoch 62: val_accuracy did not improve from 0.93642
# 127/127 [==============================] - 0s 670us/step - loss: 0.0778 - accuracy: 0.9787 - val_loss: 0.4247 - val_accuracy: 0.8728
# Epoch 63/200
#  83/127 [==================>...........] - ETA: 0s - loss: 0.0893 - accuracy: 0.9782
# Epoch 63: val_accuracy did not improve from 0.93642
# 127/127 [==============================] - 0s 734us/step - loss: 0.0788 - accuracy: 0.9797 - val_loss: 0.4377 - val_accuracy: 0.8555
# Epoch 64/200
#  86/127 [===================>..........] - ETA: 0s - loss: 0.0889 - accuracy: 0.9782
# Epoch 64: val_accuracy did not improve from 0.93642
# 127/127 [==============================] - 0s 709us/step - loss: 0.0836 - accuracy: 0.9797 - val_loss: 0.3287 - val_accuracy: 0.8902

# %%
# Visualize the training history to see whether you're overfitting.
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['TRAIN', 'VAL'], loc='lower right')
plt.show()

# %%
# Evaluate the model using the TEST dataset
loss, accuracy = model.evaluate(X_test, y_test)
# Out:
# 6/6 [==============================] - 0s 773us/step - loss: 0.2805 - accuracy: 0.9075

# %% [markdown]
# ### Draw the confusion matrix to better understand the model performance

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  """Plots the confusion matrix."""
  if normalize:
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    print("Normalized confusion matrix")
  else:
    print('Confusion matrix, without normalization')

  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=55)
  plt.yticks(tick_marks, classes)
  fmt = '.2f' if normalize else 'd'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], fmt),
              horizontalalignment="center",
              color="white" if cm[i, j] > thresh else "black")

  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.tight_layout()

# Classify pose in the TEST dataset using the trained model
y_pred = model.predict(X_test)

# Convert the prediction result to class name
y_pred_label = [class_names[i] for i in np.argmax(y_pred, axis=1)]
y_true_label = [class_names[i] for i in np.argmax(y_test, axis=1)]

# Plot the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))
plot_confusion_matrix(cm,
                      class_names,
                      title ='Confusion Matrix of Pose Classification Model')

# Print the classification report
print('\nClassification Report:\n', classification_report(y_true_label,
                                                          y_pred_label))
# Out:
# 6/6 [==============================] - 0s 670us/step
# Confusion matrix, without normalization
#
# Classification Report:
#                  precision    recall  f1-score   support
#
# plank_HighHead       0.73      1.00      0.85        30
#  plank_HighHip       1.00      1.00      1.00        28
# plank_standard       1.00      0.95      0.97        19
# squat_forerake       1.00      1.00      1.00        24
#  squat_shallow       0.92      1.00      0.96        33
# squat_standard       0.85      0.52      0.65        21
#          stand       1.00      0.72      0.84        18
#
#       accuracy                           0.91       173
#      macro avg       0.93      0.88      0.89       173
#   weighted avg       0.92      0.91      0.90       173

# %% [markdown]
# ### (Optional) Investigate incorrect predictions
#
# You can look at the poses from the `TEST` dataset that were incorrectly predicted to see whether the model accuracy can be improved.
#
# Note: This only works if you have run step 1 because you need the pose image files on your local machine to display them.

# %%
if is_skip_step_1:
    raise RuntimeError('You must have run step 1 to run this cell.')

# If step 1 was skipped, skip this step.
IMAGE_PER_ROW = 3
MAX_NO_OF_IMAGE_TO_PLOT = 1000

# Extract the list of incorrectly predicted poses
false_predict = [id_in_df for id_in_df in range(len(y_test)) \
                if y_pred_label[id_in_df] != y_true_label[id_in_df]]
if len(false_predict) > MAX_NO_OF_IMAGE_TO_PLOT:
    false_predict = false_predict[:MAX_NO_OF_IMAGE_TO_PLOT]

# Plot the incorrectly predicted images
row_count = len(false_predict) // IMAGE_PER_ROW + 1
fig = plt.figure(figsize=(10 * IMAGE_PER_ROW, 10 * row_count))
for i, id_in_df in enumerate(false_predict):
    ax = fig.add_subplot(row_count, IMAGE_PER_ROW, i + 1)
    image_path = os.path.join(images_out_test_folder,
                              df_test.iloc[id_in_df]['file_name'])

    image = cv2.imread(image_path)
    plt.title("Predict: %s; Actual: %s" %
              (y_pred_label[id_in_df], y_true_label[id_in_df]))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ## Part 3: Convert the pose classification model to TensorFlow Lite
#
# You'll convert the Keras pose classification model to the TensorFlow Lite format so that you can deploy it to mobile apps, web browsers and edge devices. When converting the model, you'll apply [dynamic range quantization](https://www.tensorflow.org/lite/performance/post_training_quant) to reduce the pose classification TensorFlow Lite model size by about 4 times with insignificant accuracy loss.
#
# Note: TensorFlow Lite supports multiple quantization schemes. See the [documentation](https://www.tensorflow.org/lite/performance/model_optimization) if you are interested to learn more.

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

print('Model size: %dKB' % (len(tflite_model) / 1024))

with open('pose_classifier.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /var/folders/qf/bt6y95cj0nzcf8gnm98073_w0000gn/T/tmp9g27or37/assets
# INFO:tensorflow:Assets written to: /var/folders/qf/bt6y95cj0nzcf8gnm98073_w0000gn/T/tmp9g27or37/assets
# Model size: 27KB
# 2023-08-05 17:58:49.016117: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
# 2023-08-05 17:58:49.016136: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
# 2023-08-05 17:58:49.016336: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: /var/folders/qf/bt6y95cj0nzcf8gnm98073_w0000gn/T/tmp9g27or37
# 2023-08-05 17:58:49.018143: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
# 2023-08-05 17:58:49.018154: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: /var/folders/qf/bt6y95cj0nzcf8gnm98073_w0000gn/T/tmp9g27or37
# 2023-08-05 17:58:49.024936: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:357] MLIR V1 optimization pass is not enabled
# 2023-08-05 17:58:49.026247: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
# 2023-08-05 17:58:49.063819: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: /var/folders/qf/bt6y95cj0nzcf8gnm98073_w0000gn/T/tmp9g27or37
# 2023-08-05 17:58:49.074282: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 57965 microseconds.
# 2023-08-05 17:58:49.112651: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.

# %% [markdown]
# Then you'll write the label file which contains mapping from the class indexes to the human readable class names.

# %%
with open('pose_labels.txt', 'w') as f:
    f.write('\n'.join(class_names))

# %% [markdown]
# As you've applied quantization to reduce the model size, let's evaluate the quantized TFLite model to check whether the accuracy drop is acceptable.

# %%
def evaluate_model(interpreter, X, y_true):
    """Evaluates the given TFLite model and return its accuracy."""
    input_index = interpreter.get_input_details()[0]["index"]
    output_index = interpreter.get_output_details()[0]["index"]
    
    # Run predictions on all given poses.
    y_pred = [] 
    for i in range(len(y_true)):
        # Pre-processing: add batch dimension and convert to float32 to match with
        # the model's input data format.
        test_image = X[i:i + 1].astype('float32')
        interpreter.set_tensor(input_index, test_image)

        # Run inference.
        interpreter.invoke()

        # Post-processing: remove batch dimension and find the class with highest
        # probability.
        output = interpreter.tensor(output_index)
        predicted_label = np.argmax(output()[0])
        y_pred.append(predicted_label)

    # Compare prediction results with ground truth labels to calculate accuracy.
    y_pred = keras.utils.to_categorical(y_pred)
    return accuracy_score(y_true, y_pred) 


# Evaluate the accuracy of the converted TFLite model
classifier_interpreter = tf.lite.Interpreter(model_content=tflite_model)
classifier_interpreter.allocate_tensors()
print('Accuracy of TFLite model: %s' %
      evaluate_model(classifier_interpreter, X_test, y_test))
# Out:
# Accuracy of TFLite model: 0.7225433526011561
# INFO: Applying 1 TensorFlow Lite delegate(s) lazily.
